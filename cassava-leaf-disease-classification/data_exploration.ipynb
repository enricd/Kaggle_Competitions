# %%
import os
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import torchvision
import random
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Data

# %%
path = Path('data')
os.listdir('./data')
# Out:
# ['.ipynb_checkpoints',
#  'train.csv',
#  'train_old.csv',
#  'train_imgs',
#  'train_extra.csv',
#  'sample_submission.csv',
#  'label_num_to_disease_map.json',
#  'test_imgs',
#  'extra']

# %%
train = pd.read_csv(path/'train.csv')
train
# Out:
#              image_id  label
# 0      1000015157.jpg      0
# 1      1000201771.jpg      3
# 2       100042118.jpg      1
# 3      1000723321.jpg      1
# 4      1000812911.jpg      3
# ...               ...    ...
# 21392   999068805.jpg      3
# 21393   999329392.jpg      3
# 21394   999474432.jpg      1
# 21395   999616605.jpg      4
# 21396   999998473.jpg      4
#
# [21397 rows x 2 columns]

# %% [markdown]
# ## Class distribution

# %%
# dataset is balanced?

train.label.hist()
plt.show()

# %%
# no, it is unbalanced, upsampling with DA would be a good option

train.label.value_counts()
# Out:
# 3    13158
# 4     2577
# 2     2386
# 1     2189
# 0     1087
# Name: label, dtype: int64

# %% [markdown]
# ## Image visualization

# %%
import torch
import torchvision

transform = torchvision.transforms.Compose([
    #torchvision.transforms.Resize((32,32)),
    torchvision.transforms.RandomResizedCrop((550,550), scale=(0.9,0.9), interpolation=2),
])

# %%
r, c = 3, 5
fig = plt.figure(figsize=(3*c, 3*r))
for _r in range(r):
    for _c in range (c):
        ax = plt.subplot(r, c, _r*c + _c + 1)
        ix = _r*c + _c + 1
        #ix = random.randint(0, len(train))
        img = torchvision.io.read_image(str(path/'train_imgs'/train['image_id'][ix]))
        img = transform(img)
        label = train['label'][ix]
        plt.axis("off")
        plt.imshow(img.permute(1,2,0))
        plt.title(label)
plt.tight_layout()
plt.show()

# %%
r, c = 3, 5
fig = plt.figure(figsize=(3*c, 3*r))
for _r in range(r):
    for _c in range (c):
        ax = plt.subplot(r, c, _r*c + _c + 1)
        ix = _r*c + _c + 1
        #ix = random.randint(0, len(train))
        img = torchvision.io.read_image(str(path/'train_imgs'/train['image_id'][ix]))
        img = transform(img)
        label = train['label'][ix]
        plt.axis("off")
        plt.imshow(img.permute(1,2,0))
        plt.title(label)
plt.tight_layout()
plt.show()

# %%
# resolution and type of the images

img.shape, img.dtype, img.max(), img.min()
# Out:
# (torch.Size([3, 600, 800]),
#  torch.uint8,
#  tensor(255, dtype=torch.uint8),
#  tensor(0, dtype=torch.uint8))

# %% [markdown]
# ## Test Data

# %%
os.listdir(path/'test_images')
# Out:
# ['2216849948.jpg']

# %%
sample_submission = pd.read_csv(path/'sample_submission.csv')
sample_submission
# Out:
#          image_id  label
# 0  2216849948.jpg      4

# %% [markdown]
# ## DataModule

# %%
# Resize with transforms from torchvision

transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((32,32))
])

# %%
# calling the Dataset and DataModule script in the src folder which was developed in a cell here

from src import DataModule
# Out:
# Traceback (most recent call last):
#
#   File "/home/enric/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-12-84f69b57e1a6>", line 3, in <module>
#     from src import DataModule
#
#   File "/home/enric/Documents/code/cassava-leaf-disease-classification/src/__init__.py", line 2, in <module>
#     from .model import Model
#
#   File "/home/enric/Documents/code/cassava-leaf-disease-classification/src/model.py", line 42
#     self.resnet = getattr(torchvision.models, self.hparams. (pretrained=True)
#                                                             ^
# SyntaxError: invalid syntax

# %%
dm = DataModule(subset=0.1)

dm.setup()

# %%
r, c = 3, 5
fig = plt.figure(figsize=(3*c, 3*r))
ds = dm.train_ds
for _r in range(r):
    for _c in range (c):
        ax = plt.subplot(r, c, _r*c + _c + 1)
        ix = random.randint(0, len(ds)-1)
        img, label = ds[ix]
        plt.axis("off")
        plt.imshow(img.permute(1,2,0))
        plt.title(label.item())
plt.tight_layout()
plt.show()

# %%
img.shape, img.dtype, img.max(), img.min()

# %%
# testing the dataloader

dl = dm.train_dataloader()

imgs, labels = next(iter(dl))

imgs.shape, imgs.dtype, imgs.max(), imgs.min()

# %%
a, b = ds[1]
